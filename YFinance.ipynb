# %%
import pandas as pd
import yfinance as yf
from yahoofinancials import YahooFinancials

# %% [markdown]
# ## Downloading Stocks info for Tesla motors using YFinance

# %%
tsla_df = yf.download('TSLA', 
                      start='2019-01-01', 
                      end='2019-12-31', 
                      progress=False)
tsla_df.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2018-12-31  67.557999  67.842003  65.052002  66.559998  66.559998  31511500
# 2019-01-02  61.220001  63.026001  59.759998  62.023998  62.023998  58293000
# 2019-01-03  61.400002  61.880001  59.476002  60.071999  60.071999  34826000
# 2019-01-04  61.200001  63.599998  60.546001  63.537998  63.537998  36970500
# 2019-01-07  64.344002  67.348000  63.549999  66.991997  66.991997  37756000

# %% [markdown]
# ### info — prints out a JSON containing a lot of interesting information, such as the company’s full name, business summary, the industry in which it operates, on which exchange it is listed (also the country, time zone) and many more.

# %%
ticker.info
# Out:
# {'zip': '94304',
#  'sector': 'Consumer Cyclical',
#  'fullTimeEmployees': 70757,
#  'longBusinessSummary': 'Tesla, Inc. designs, develops, manufactures, leases, and sells electric vehicles, and energy generation and storage systems in the United States, China, and internationally. The company operates in two segments, Automotive, and Energy Generation and Storage. The Automotive segment offers electric vehicles, as well as sells automotive regulatory credits. It provides sedans and sport utility vehicles through direct and used vehicle sales, a network of Tesla Superchargers, and in-app upgrades; and purchase financing and leasing services. This segment is also involved in the provision of non-warranty after-sales vehicle services, sale of used vehicles, retail merchandise, and vehicle insurance, as well as sale of products through its subsidiaries to third party customers; services for electric vehicles through its company-owned service locations, and Tesla mobile service technicians; and vehicle limited warranties and extended service plans. The Energy Generation and Storage segment engages in the design, manufacture, installation, sale, and leasing of solar energy generation and energy storage products, and related services to residential, commercial, and industrial customers and utilities through its website, stores, and galleries, as well as through a network of channel partners. This segment also offers service and repairs to its energy product customers, including under warranty; and various financing options to its solar customers. The company was formerly known as Tesla Motors, Inc. and changed its name to Tesla, Inc. in February 2017. Tesla, Inc. was founded in 2003 and is headquartered in Palo Alto, California.',
#  'city': 'Palo Alto',
#  'phone': '650-681-5000',
#  'state': 'CA',
#  'country': 'United States',
#  'companyOfficers': [],
#  'website': 'http://www.tesla.com',
#  'maxAge': 1,
#  'address1': '3500 Deer Creek Road',
#  'industry': 'Auto Manufacturers',
#  'previousClose': 571.69,
#  'regularMarketOpen': 583.41,
#  'twoHundredDayAverage': 668.1526,
#  'trailingAnnualDividendYield': None,
#  'payoutRatio': 0,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 592.8699,
#  'navPrice': None,
#  'averageDailyVolume10Day': 32780500,
#  'totalAssets': None,
#  'regularMarketPreviousClose': 571.69,
#  'fiftyDayAverage': 679.95544,
#  'trailingAnnualDividendRate': None,
#  'open': 583.41,
#  'toCurrency': None,
#  'averageVolume10days': 32780500,
#  'expireDate': None,
#  'yield': None,
#  'algorithm': None,
#  'dividendRate': None,
#  'exDividendDate': None,
#  'beta': 1.984491,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 570.48,
#  'priceHint': 2,
#  'currency': 'USD',
#  'trailingPE': 590.9218,
#  'regularMarketVolume': 32805737,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 568114216960,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 35609795,
#  'priceToSalesTrailing12Months': 15.807296,
#  'dayLow': 570.48,
#  'ask': 598,
#  'ytdReturn': None,
#  'askSize': 3200,
#  'volume': 32805737,
#  'fiftyTwoWeekHigh': 900.4,
#  'forwardPE': 94.3584,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': None,
#  'fiftyTwoWeekLow': 157,
#  'bid': 593.6,
#  'tradeable': False,
#  'dividendYield': None,
#  'bidSize': 900,
#  'dayHigh': 592.8699,
#  'exchange': 'NMS',
#  'shortName': 'Tesla, Inc.',
#  'longName': 'Tesla, Inc.',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '-14400000',
#  'quoteType': 'EQUITY',
#  'symbol': 'TSLA',
#  'messageBoardId': 'finmb_27444752',
#  'market': 'us_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': 15.235,
#  'beta3Year': None,
#  'profitMargins': 0.0318,
#  'enterpriseToEbitda': 120.313,
#  '52WeekChange': 2.6241288,
#  'morningStarRiskRating': None,
#  'forwardEps': 6.25,
#  'revenueQuarterlyGrowth': None,
#  'sharesOutstanding': 963329984,
#  'fundInceptionDate': None,
#  'annualReportExpenseRatio': None,
#  'bookValue': 23.901,
#  'sharesShort': 41382433,
#  'sharesPercentSharesOut': 0.043,
#  'fundFamily': None,
#  'lastFiscalYearEnd': 1609372800,
#  'heldPercentInstitutions': 0.44210997,
#  'netIncomeToCommon': 1112000000,
#  'trailingEps': 0.998,
#  'lastDividendValue': None,
#  'SandP52WeekChange': 0.41299164,
#  'priceToBook': 24.674282,
#  'heldPercentInsiders': 0.19629999,
#  'nextFiscalYearEnd': 1672444800,
#  'mostRecentQuarter': 1617148800,
#  'shortRatio': 1.27,
#  'sharesShortPreviousMonthDate': 1617148800,
#  'floatShares': 774267214,
#  'enterpriseValue': 547544399872,
#  'threeYearAverageReturn': None,
#  'lastSplitDate': 1598832000,
#  'lastSplitFactor': '5:1',
#  'legalType': None,
#  'lastDividendDate': None,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': 26.375,
#  'dateShortInterest': 1619740800,
#  'pegRatio': 3.66,
#  'lastCapGain': None,
#  'shortPercentOfFloat': 0.053400002,
#  'sharesShortPriorMonth': 46269602,
#  'impliedSharesOutstanding': None,
#  'category': None,
#  'fiveYearAverageReturn': None,
#  'regularMarketPrice': 589.74,
#  'logo_url': 'https://logo.clearbit.com/tesla.com'}

# %%
Tesla = ticker.info
print(Tesla['sector'])

print(Tesla['fullTimeEmployees'])
print(Tesla['bookValue'])
# Out:
# Consumer Cyclical
# 70757
# 23.901

# %% [markdown]
# ### recommendations — contains a historical list of recommendations made by analysts

# %%
ticker.recommendations
# Out:
#                                   Firm    To Grade From Grade Action
# Date
# 2012-02-16 07:42:00          JP Morgan  Overweight              main
# 2012-02-16 13:53:00         Wunderlich        Hold              down
# 2012-02-17 06:17:00         Oxen Group         Buy              init
# 2012-03-26 07:31:00         Wunderlich         Buy                up
# 2012-05-22 05:57:00        Maxim Group         Buy              init
# ...                                ...         ...        ...    ...
# 2021-04-20 12:10:31             Mizuho         Buy              main
# 2021-04-23 12:17:41     Morgan Stanley  Overweight              main
# 2021-04-27 10:45:17      Goldman Sachs         Buy              main
# 2021-04-27 13:07:23      Credit Suisse     Neutral              reit
# 2021-04-27 13:09:34  Canaccord Genuity         Buy              main
#
# [389 rows x 4 columns]

# %% [markdown]
# ### actions — displays actions such as dividends and splits

# %%
ticker.actions
# Out:
#             Dividends  Stock Splits
# Date
# 2020-08-31        0.0           5.0

# %% [markdown]
# ### major_holders - shows the major holders

# %%
ticker.major_holders
# Out:
#         0                                      1
# 0  19.63%        % of Shares Held by All Insider
# 1  44.21%       % of Shares Held by Institutions
# 2  55.01%        % of Float Held by Institutions
# 3    2637  Number of Institutions Holding Shares

# %% [markdown]
# ### institutional_holders — shows the institutional holders, such as on the following image:

# %%
ticker.institutional_holders
# Out:
#                               Holder    Shares Date Reported   % Out  \
# 0         Vanguard Group, Inc. (The)  57814310    2020-12-30  0.0600
# 1                     Blackrock Inc.  50242363    2021-03-30  0.0522
# 2            Capital World Investors  46249648    2020-12-30  0.0480
# 3           State Street Corporation  29550379    2020-12-30  0.0307
# 4        Baillie Gifford and Company  16216060    2021-03-30  0.0168
# 5                           FMR, LLC  15311711    2020-12-30  0.0159
# 6      Geode Capital Management, LLC  11971355    2021-03-30  0.0124
# 7            Jennison Associates LLC  10739998    2021-03-30  0.0111
# 8         Northern Trust Corporation   8262415    2021-03-30  0.0086
# 9  Norges Bank Investment Management   7790070    2020-12-30  0.0081
#
#          Value
# 0  40797824137
# 1  33558381518
# 2  32636989104
# 3  20852815948
# 4  10831192955
# 5  10805015101
# 6   7996027145
# 7   7173566864
# 8   5518714850
# 9   5497218696

# %% [markdown]
# ### calendar — shows the incoming events, such as earnings

# %%
ticker.calendar
# Out:
#                                     0                    1
# Earnings Date     2021-07-20 00:00:00  2021-07-26 00:00:00
# Earnings Average                 0.95                 0.95
# Earnings Low                     0.62                 0.62
# Earnings High                    1.16                 1.16
# Revenue Average           11232800000          11232800000
# Revenue Low                9500000000           9500000000
# Revenue High              12826900000          12826900000

# %% [markdown]
# ### Downloading the entire history of Tesla’s stock prices:

# %%
ticker = yf.Ticker('TSLA')

tsla_df = ticker.history(period="max")

tsla_df['Close'].plot(title="TSLA's stock price")
# Out:
# <AxesSubplot:title={'center':"TSLA's stock price"}, xlabel='Date'>
